# %% [markdown]
# # Descripción y exploración de variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
'''Carga de Datos Diarios  de todas las variables'''
nasapp = pd.read_csv('../datos/por_variables/nasa_diario_pp.csv')
nasatmed = pd.read_csv('../datos/por_variables/nasa_diario_tmed.csv')
nasatmax = pd.read_csv('../datos/por_variables/nasa_diario_tmax.csv')
nasatmin = pd.read_csv('../datos/por_variables/nasa_diario_tmin.csv')
nasahmed = pd.read_csv('../datos/por_variables/nasa_diario_hmed.csv')
chirpp = pd.read_csv('../datos/por_variables/chirps_diario_pp.csv')
obspp = pd.read_csv('../datos/por_variables/obs_diario_pp.csv')
obstmax = pd.read_csv('../datos/por_variables/obs_diario_tmax.csv')
obstmin = pd.read_csv('../datos/por_variables/obs_diario_tmin.csv')
obstmed = pd.read_csv('../datos/por_variables/obs_diario_tmed.csv')
obshmax = pd.read_csv('../datos/por_variables/obs_diario_tmed.csv')
obstmin = pd.read_csv('../datos/por_variables/obs_diario_tmed.csv')
obstmed = pd.read_csv('../datos/por_variables/obs_diario_tmed.csv')

# %%
'''Carga de Datos Mensuales  de todas las variables'''
mnasapp = pd.read_csv('../datos/por_variables/nasa_mensual_pp.csv')
mnasatmed = pd.read_csv('../datos/por_variables/nasa_mensual_tmed.csv')
mnasatmax = pd.read_csv('../datos/por_variables/nasa_mensual_tmax.csv')
mnasatmin = pd.read_csv('../datos/por_variables/nasa_mensual_tmin.csv')
mnasahmed = pd.read_csv('../datos/por_variables/nasa_mensual_hmed.csv')
mchirpp = pd.read_csv('../datos/por_variables/chirps_mensual_pp.csv')
mobspp = pd.read_csv('../datos/por_variables/obs_mensual_pp.csv')
mobstmax = pd.read_csv('../datos/por_variables/obs_mensual_tmax.csv')
mobstmin = pd.read_csv('../datos/por_variables/obs_mensual_tmin.csv')
mobstmed = pd.read_csv('../datos/por_variables/obs_mensual_tmed.csv')
mobshmax = pd.read_csv('../datos/por_variables/obs_mensual_hmax.csv')
mobshmin = pd.read_csv('../datos/por_variables/obs_mensual_hmin.csv')
mobshmed = pd.read_csv('../datos/por_variables/obs_mensual_hmed.csv')

# %%
'''Descripcion de la estacion Aeropuerto Oruro - datos diarios'''
obspp['100'].describe()
# Out:
# count    14415.000000
# mean         1.189837
# std          3.704769
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         66.700000
# Name: 100, dtype: float64

# %%
'''Descripcion de la estacion Aeropuerto Oruro - datos mensuales'''
mobspp['100'].describe()
# Out:
# count    480.000000
# mean      35.732292
# std       42.899312
# min        0.000000
# 25%        3.750000
# 50%       19.900000
# 75%       53.925000
# max      233.100000
# Name: 100, dtype: float64

# %%
esta = '100'
'''GRaficas mensual pp'''
mobspp.loc[0:,esta].plot(figsize=(20,10), color='blue')
# Out:
# <AxesSubplot:>

# %%
'''GRaficas mensual tmax'''
mnasatmax.loc[0:,esta].plot(figsize=(20,10), color='blue')
# Out:
# <AxesSubplot:>

# %%
'''GRaficas mensual tmin'''
mnasatmin.loc[0:,esta].plot(figsize=(20,10), color='blue')
# Out:
# <AxesSubplot:>

# %%
'''GRaficas mensual tmed'''
mnasatmed.loc[0:,esta].plot(figsize=(20,10), color='blue')
# Out:
# <AxesSubplot:>

# %%
'''GRaficas mensual hmed'''
mnasahmed.loc[0:,esta].plot(figsize=(20,10), color='blue')
# Out:
# <AxesSubplot:>
